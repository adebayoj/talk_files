# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import pandas as pd
import seaborn as sns

# sns.set_context('poster')  #Everything is larger
sns.set_context('paper')  #Everything is smaller
# sns.set_context('talk')  #Everything is sized for a presentation

matplotlib.rcParams['font.family'] = "serif"

# %%
plt.xkcd() 
#plt.style.use('xkcd')

x = ['2010', '2011',
     '2012', '2013', '2014', '2015', '2016', '2017',
     '2018', '2019']
energy = [1320, 1340, 1690, 1770, 1930, 2180, 2570,
          3330, 6480, 5340]
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='magenta')
#plt.xlabel("Energy Source")
plt.ylabel("# Publications")
plt.title("Interpretability & DNN Papers")
plt.xticks(x_pos, x, rotation='vertical')
plt.savefig('interpretability_papers.pdf', bbox_inches='tight', dpi=750)
plt.show()

# %%
accuracy = [54, 53, 59, 89]
epsilon = [2, 10, 21, 94]
plt.plot(epsilon, accuracy, 'bo-')
plt.xlim([0, 100])
plt.ylim([0, 100])
plt.xlabel("Epislon")
plt.ylabel("MIA Reconstruction Accuracy")
plt.title("Privacy vs Local Explanability")
plt.savefig('privacy_vs_local_explanability.pdf', bbox_inches='tight', dpi=750)
